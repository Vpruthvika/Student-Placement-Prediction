# %%
print("OK")

# %%
'''
mongodb+srv://<db_username>:<db_password>@cluster0.l6m738q.mongodb.net/?appName=Cluster0
'''

# %%
import pandas as pd

# %%
df= pd.read_csv("placementdata.csv")
df.head()

# %%
df.shape

# %%
df.columns

# %%
data=df.to_dict(orient="records")
data

# %%
len(data)

# %%
DB_NAME = "Placement_Prediction"
COLLECTION_NAME = "Placement_Prediction"

CONNECTION_URL ="mongodb+srv://pruth:Pruth2005@cluster0.l6m738q.mongodb.net/?appName=Cluster0"

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)

try:
    print(client.list_database_names())
    print("Connected Successfully!")
except Exception as e:
    print(e)
